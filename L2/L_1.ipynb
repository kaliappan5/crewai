# %% [markdown]
# # L1: Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# ### Website Project Breakdown
#
# #### Project Requirements Overview:
#
# The objective is to create a comprehensive website for a small business. Each task will be meticulously evaluated for scope, timelines, dependencies, and deliverables.
#
# ---
#
# #### Task Breakdown
#
# 1. **Create a Responsive Design**
#
#    - **Description**: Develop a design layout that adapts seamlessly to various screen sizes including desktops, tablets, and smartphones.
#    - **Scope**: Wireframe creation, mockups, responsiveness testing.
#    - **Timeline**: 2 weeks (Day 1 - Day 14)
#    - **Dependencies**: None
#    - **Deliverables**: Responsive design prototypes.
#
# 2. **Implement a Modern User Interface**
#
#    - **Description**: Integrate a clean and visually appealing UI based on the mockups established in the design phase.
#    - **Scope**: UI components coding, color palette selection, typography, and imagery integration.
#    - **Timeline**: 3 weeks (Day 15 - Day 35)
#    - **Dependencies**: Completion of responsive design.
#    - **Deliverables**: Functional UI on the initial pages.
#
# 3. **Develop User-Friendly Navigation System**
#
#    - **Description**: Create an intuitive menu structure that enhances usability.
#    - **Scope**: Menu design, sub-menu organization, breadcrumb navigation setup.
#    - **Timeline**: 1 week (Day 36 - Day 42)
#    - **Dependencies**: Completion of UI implementation.
#    - **Deliverables**: Functional navigation system.
#
# 4. **Include an "About Us" Page**
#
#    - **Description**: Develop a page that outlines the company's history, values, and mission.
#    - **Scope**: Content writing, page design.
#    - **Timeline**: 1 week (Day 43 - Day 49)
#    - **Dependencies**: Completion of navigation system.
#    - **Deliverables**: Live "About Us" page.
#
# 5. **Design a "Services" Page**
#
#    - **Description**: Showcase the company's offerings with detailed descriptions and visuals if necessary.
#    - **Scope**: Content finalization, design integration.
#    - **Timeline**: 1 week (Day 50 - Day 56)
#    - **Dependencies**: Completion of "About Us" page.
#    - **Deliverables**: Live "Services" page.
#
# 6. **Create "Contact Us" Page**
#
#    - **Description**: Develop a communication page featuring a contact form and integrated Google Maps for location.
#    - **Scope**: Form functionality, map integration, validation checks.
#    - **Timeline**: 1 week (Day 57 - Day 63)
#    - **Dependencies**: Completion of the "Services" page.
#    - **Deliverables**: Live "Contact Us" page.
#
# 7. **Implement a Blog Section**
#
#    - **Description**: Create a section for posts that can be updated regularly with industry news and business updates.
#    - **Scope**: Blog post layout, content management setup.
#    - **Timeline**: 2 weeks (Day 64 - Day 77)
#    - **Dependencies**: Completion of "Contact Us" page.
#    - **Deliverables**: Functional Blog section.
#
# 8. **Ensure Fast Loading Times and SEO Optimization**
#
#    - **Description**: Optimize website performance and search engine visibility.
#    - **Scope**: Image optimization, minifying CSS/JS, SEO best practices implementation.
#    - **Timeline**: 2 weeks (Day 78 - Day 91)
#    - **Dependencies**: Completion of all pages.
#    - **Deliverables**: Performance reports, SEO compliant site.
#
# 9. **Integrate Social Media Links & Sharing**
#
#    - **Description**: Enable users to share content and connect through social media.
#    - **Scope**: Social media button placement and linkage.
#    - **Timeline**: 1 week (Day 92 - Day 98)
#    - **Dependencies**: Completion of SEO optimization.
#    - **Deliverables**: Active social media integration.
#
# 10. **Include Testimonials Section**
#
#     - **Description**: Develop a section to showcase customer feedback, helping to build credibility.
#     - **Scope**: Testimonial collection, page design.
#     - **Timeline**: 1 week (Day 99 - Day 105)
#     - **Dependencies**: Completion of the Blog section.
#     - **Deliverables**: Live testimonials section.
#
# ---
#
# ### Gantt Chart Visualization
#
# ```plaintext
# | Task                                   |   Week 1   |   Week 2   |   Week 3   |   Week 4   |   Week 5   |   Week 6   |   Week 7   |   Week 8   |   Week 9   |   Week 10  |    Week 11   |
# |----------------------------------------|------------|------------|------------|------------|------------|------------|------------|------------|------------|-------------|---------------|
# | Create Responsive Design               | ████████   |            |            |            |            |            |            |            |            |             |               |
# | Modern User Interface                  |            | ███████████|            |            |            |            |            |            |            |             |               |
# | User-Friendly Navigation System        |            |            | ████████   |            |            |            |            |            |            |             |               |
# | "About Us" Page                       |            |            |            | ████████   |            |            |            |            |            |             |               |
# | "Services" Page                       |            |            |            |            | ████████   |            |            |            |            |             |               |
# | "Contact Us" Page                     |            |            |            |            |            | ████████   |            |            |            |             |               |
# | Blog Section                          |            |            |            |            |            |            | ████████   |            |            |             |               |
# | SEO Optimization                      |            |            |            |            |            |            |            | ████████   |            |             |               |
# | Social Media Integration              |            |            |            |            |            |            |            |            | ████████   |             |               |
# | Testimonials Section                  |            |            |            |            |            |            |            |            |            | ████████    |               |
# ```
#
# ---
#
# ### Team Roles and Responsibilities
#
# - **John Doe (Project Manager)**: Overall project oversight, ensuring timelines, and communication among team members.
# - **Jane Doe (Software Engineer)**: Responsible for backend development, coding, and implementation of features.
# - **Bob Smith (Designer)**: Creating and finalizing UI/UX design elements and ensuring responsive design.
# - **Alice Johnson (QA Engineer)**: Testing functionality and user experience throughout the project lifecycle.
# - **Tom Brown (QA Engineer)**: Focused on performance testing, SEO validation, and overall site quality assurance.
#
# ---
#
# By implementing this detailed project breakdown, we ensure that each phase of the website development process is thoroughly planned, on schedule, and meets the desired quality standards. This plan will guide the effort to create a successful and efficient online presence for the small business.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Detailed Estimation Report for the Website Project
#
# This report meticulously outlines the estimated time, resources, and effort required to complete each task involved in the website project. Additionally, it includes a summary of risks and uncertainties associated with these estimations.
#
# ---
#
# #### 1. Create a Responsive Design
#
# - **Estimated Time**: 2 weeks (Day 1 - Day 14)
# - **Resources Required**:
#   - 1 Designer (Bob Smith)
#   - Design Software (Figma/Adobe XD)
# - **Effort**: 80 hours (4 hours/day)
# - **Deliverables**: Responsive design prototypes.
# - **Risks**: Delays in design approval can impede subsequent tasks.
#
# ---
#
# #### 2. Implement a Modern User Interface
#
# - **Estimated Time**: 3 weeks (Day 15 - Day 35)
# - **Resources Required**:
#   - 1 Software Engineer (Jane Doe)
#   - 1 Designer (Bob Smith)
#   - Development Tools (IDE, version control)
# - **Effort**: 120 hours (40 hours/week)
# - **Deliverables**: Functional UI on the initial pages.
# - **Risks**: Potential miscommunication about design intent may lead to rework.
#
# ---
#
# #### 3. Develop User-Friendly Navigation System
#
# - **Estimated Time**: 1 week (Day 36 - Day 42)
# - **Resources Required**:
#   - 1 Software Engineer (Jane Doe)
#   - 1 QA Engineer (Alice Johnson)
# - **Effort**: 40 hours (5 hours/day)
# - **Deliverables**: Functional navigation system.
# - **Risks**: Changes in site structure could require redesigning the navigation.
#
# ---
#
# #### 4. Include an "About Us" Page
#
# - **Estimated Time**: 1 week (Day 43 - Day 49)
# - **Resources Required**:
#   - 1 Content Writer (not specified)
#   - 1 Designer (Bob Smith)
#   - 1 QA Engineer (Alice Johnson)
# - **Effort**: 40 hours (content writing + design integration)
# - **Deliverables**: Live "About Us" page.
# - **Risks**: Content creation could experience delays due to stakeholder feedback.
#
# ---
#
# #### 5. Design a "Services" Page
#
# - **Estimated Time**: 1 week (Day 50 - Day 56)
# - **Resources Required**:
#   - 1 Content Writer
#   - 1 Designer (Bob Smith)
#   - 1 QA Engineer (Alice Johnson)
# - **Effort**: 40 hours
# - **Deliverables**: Live "Services" page.
# - **Risks**: Additional service offerings needing representation may arise late in design.
#
# ---
#
# #### 6. Create "Contact Us" Page
#
# - **Estimated Time**: 1 week (Day 57 - Day 63)
# - **Resources Required**:
#   - 1 Software Engineer (Jane Doe)
#   - 1 QA Engineer (Alice Johnson)
# - **Effort**: 40 hours
# - **Deliverables**: Live "Contact Us" page.
# - **Risks**: Integration issues with Google Maps API or form validation could delay delivery.
#
# ---
#
# #### 7. Implement a Blog Section
#
# - **Estimated Time**: 2 weeks (Day 64 - Day 77)
# - **Resources Required**:
#   - 1 Software Engineer (Jane Doe)
#   - 1 Content Management System (CMS) setup tools.
# - **Effort**: 80 hours
# - **Deliverables**: Functional Blog section.
# - **Risks**: Lack of content prior to launch could affect the readiness of the section.
#
# ---
#
# #### 8. Ensure Fast Loading Times and SEO Optimization
#
# - **Estimated Time**: 2 weeks (Day 78 - Day 91)
# - **Resources Required**:
#   - 1 Software Engineer (Jane Doe)
#   - 1 QA Engineer (Tom Brown)
#   - Performance testing tools.
# - **Effort**: 80 hours
# - **Deliverables**: Performance reports, SEO compliant site.
# - **Risks**: Unforeseen performance issues could require extensive revisions.
#
# ---
#
# #### 9. Integrate Social Media Links & Sharing
#
# - **Estimated Time**: 1 week (Day 92 - Day 98)
# - **Resources Required**:
#   - 1 Software Engineer (Jane Doe)
#   - Social media platform guidelines.
# - **Effort**: 40 hours
# - **Deliverables**: Active social media integration.
# - **Risks**: Integration conflicts with existing site features can occur.
#
# ---
#
# #### 10. Include Testimonials Section
#
# - **Estimated Time**: 1 week (Day 99 - Day 105)
# - **Resources Required**:
#   - 1 Content Writer
#   - 1 Designer (Bob Smith)
# - **Effort**: 40 hours
# - **Deliverables**: Live testimonials section.
# - **Risks**: Delay in collecting testimonials could hinder progress.
#
# ---
#
# ### Summary of Risks and Uncertainties
# 1. **Communication Delays**: Misalignment between stakeholders and development team on design and content can lead to rework.
# 2. **Resource Availability**: Unavailability of key team members could cause bottlenecks.
# 3. **Content Creation Delays**: Dependencies on content writing may introduce delays to development timelines.
# 4. **Integration Challenges**: Third-party integrations may pose unforeseen technical challenges or require additional time for resolution.
#
# By maintaining clear communication and adhering to the outlined estimations, this project aims for success while mitigating risks and uncertainties. The detailed assessment provides a roadmap to ensure that the website is delivered efficiently and on budget.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# ### Resource Allocation Chart for Website Project
#
# | Task                                       | Assigned Team Members       | Start Date | End Date   | Total Effort (hours) |
# |--------------------------------------------|------------------------------|------------|------------|-----------------------|
# | 1. Create a Responsive Design              | Bob Smith                    | Day 1      | Day 14     | 80                    |
# | 2. Implement a Modern User Interface       | Jane Doe, Bob Smith          | Day 15     | Day 35     | 120                   |
# | 3. Develop User-Friendly Navigation System  | Jane Doe, Alice Johnson      | Day 36     | Day 42     | 40                    |
# | 4. Include an "About Us" Page             | Bob Smith, Alice Johnson      | Day 43     | Day 49     | 40                    |
# | 5. Design a "Services" Page               | Bob Smith, Alice Johnson      | Day 50     | Day 56     | 40                    |
# | 6. Create "Contact Us" Page               | Jane Doe, Alice Johnson      | Day 57     | Day 63     | 40                    |
# | 7. Implement a Blog Section                | Jane Doe                     | Day 64     | Day 77     | 80                    |
# | 8. Ensure Fast Loading Times & SEO         | Jane Doe, Tom Brown          | Day 78     | Day 91     | 80                    |
# | 9. Integrate Social Media Links & Sharing  | Jane Doe                     | Day 92     | Day 98     | 40                    |
# | 10. Include Testimonials Section            | Bob Smith                    | Day 99     | Day 105    | 40                    |
#
# ### Rationale for Allocation Decisions:
#
# 1. **Creating a Responsive Design**: Bob Smith, as the Designer, is best suited for this task because it leverages his creative design skills, crucial for producing visually appealing and functional prototypes.
#
# 2. **Implementing a Modern User Interface**: This task requires collaboration to ensure design feasibility, so Jane Doe (Software Engineer) and Bob Smith (Designer) are assigned to work together. Jane's coding expertise ensures that the design translates well into functionality.
#
# 3. **Developing User-Friendly Navigation System**: Assigned to Jane Doe and Alice Johnson, this allocation utilizes Jane's technical skills for implementation alongside Alice’s QA proficiency to ensure usability before full deployment.
#
# 4. **Including an "About Us" Page**: This task is best handled by Bob Smith for design and Alice Johnson for QA, capitalizing on their combined expertise to produce a compelling and user-friendly page.
#
# 5. **Designing a "Services" Page**: Similar to the "About Us" page allocation, it requires the design talents of Bob Smith and the QA oversight from Alice Johnson to ensure high-quality delivery.
#
# 6. **Creating "Contact Us" Page**: The involved parties are Jane Doe (Software Engineer) for development and Alice Johnson (QA Engineer) for testing. This pair ensures a functional and user-friendly experience.
#
# 7. **Implementing a Blog Section**: Assigned solely to Jane Doe, this task allows her to focus on her strengths in back-end development, crucial for creating a functional content management system.
#
# 8. **Ensuring Fast Loading Times & SEO Optimization**: This task is assigned to Jane Doe and Tom Brown (QA Engineer) due to its technical nature. Jane can ensure that the code is optimized, while Tom carries out testing to guarantee performance.
#
# 9. **Integrating Social Media Links & Sharing**: Simply assigned to Jane Doe, as this relies on her familiarity with integration techniques, allowing her to apply her existing knowledge effectively.
#
# 10. **Including Testimonials Section**: This task requires design input and is thus assigned to Bob Smith, allowing him to focus on visuals while ensuring timely onboarding of content.
#
# Overall, these assignments have been made while considering the skills, availability, and existing workload of each team member. Through meticulous planning, the project aims to maximize efficiency, minimize risks, and ensure a successful website launch.

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0029
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0         19283          11989               7294                    9

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Create a Responsive Design',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Implement a Modern User Interface',
#    'estimated_time_hours': 120.0,
#    'required_resources': ['Jane Doe', 'Bob Smith']},
#   {'task_name': 'Develop User-Friendly Navigation System',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe', 'Alice Johnson']},
#   {'task_name': 'Include an "About Us" Page',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith', 'Alice Johnson']},
#   {'task_name': 'Design a "Services" Page',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith', 'Alice Johnson']},
#   {'task_name': 'Create "Contact Us" Page',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe', 'Alice Johnson']},
#   {'task_name': 'Implement a Blog Section',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Ensure Fast Loading Times & SEO',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Jane Doe', 'Tom Brown']},
#   {'task_name': 'Integrate Social Media Links & Sharing',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Include Testimonials Section',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith']}],
#  'milestones': [{'milestone_name': 'Design Phase', 'tasks': ['1', '2']},
#   {'milestone_name': 'Development Phase',
#    'tasks': ['3', '4', '5', '6', '7', '8', '9', '10']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_463b1 th {
#   font-size: 120%;
# }
# #T_463b1  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_463b1" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_463b1_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_463b1_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_463b1_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_463b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_463b1_row0_col0" class="data row0 col0" >Create a Responsive Design</td>
#       <td id="T_463b1_row0_col1" class="data row0 col1" >80.000000</td>
#       <td id="T_463b1_row0_col2" class="data row0 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_463b1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_463b1_row1_col0" class="data row1 col0" >Implement a Modern User Interface</td>
#       <td id="T_463b1_row1_col1" class="data row1 col1" >120.000000</td>
#       <td id="T_463b1_row1_col2" class="data row1 col2" >['Jane Doe', 'Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_463b1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_463b1_row2_col0" class="data row2 col0" >Develop User-Friendly Navigation System</td>
#       <td id="T_463b1_row2_col1" class="data row2 col1" >40.000000</td>
#       <td id="T_463b1_row2_col2" class="data row2 col2" >['Jane Doe', 'Alice Johnson']</td>
#     </tr>
#     <tr>
#       <th id="T_463b1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_463b1_row3_col0" class="data row3 col0" >Include an "About Us" Page</td>
#       <td id="T_463b1_row3_col1" class="data row3 col1" >40.000000</td>
#       <td id="T_463b1_row3_col2" class="data row3 col2" >['Bob Smith', 'Alice Johnson']</td>
#     </tr>
#     <tr>
#       <th id="T_463b1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_463b1_row4_col0" class="data row4 col0" >Design a "Services" Page</td>
#       <td id="T_463b1_row4_col1" class="data row4 col1" >40.000000</td>
#       <td id="T_463b1_row4_col2" class="data row4 col2" >['Bob Smith', 'Alice Johnson']</td>
#     </tr>
#     <tr>
#       <th id="T_463b1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_463b1_row5_col0" class="data row5 col0" >Create "Contact Us" Page</td>
#       <td id="T_463b1_row5_col1" class="data row5 col1" >40.000000</td>
#       <td id="T_463b1_row5_col2" class="data row5 col2" >['Jane Doe', 'Alice Johnson']</td>
#     </tr>
#     <tr>
#       <th id="T_463b1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_463b1_row6_col0" class="data row6 col0" >Implement a Blog Section</td>
#       <td id="T_463b1_row6_col1" class="data row6 col1" >80.000000</td>
#       <td id="T_463b1_row6_col2" class="data row6 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_463b1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_463b1_row7_col0" class="data row7 col0" >Ensure Fast Loading Times & SEO</td>
#       <td id="T_463b1_row7_col1" class="data row7 col1" >80.000000</td>
#       <td id="T_463b1_row7_col2" class="data row7 col2" >['Jane Doe', 'Tom Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_463b1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_463b1_row8_col0" class="data row8 col0" >Integrate Social Media Links & Sharing</td>
#       <td id="T_463b1_row8_col1" class="data row8 col1" >40.000000</td>
#       <td id="T_463b1_row8_col2" class="data row8 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_463b1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_463b1_row9_col0" class="data row9 col0" >Include Testimonials Section</td>
#       <td id="T_463b1_row9_col1" class="data row9 col1" >40.000000</td>
#       <td id="T_463b1_row9_col2" class="data row9 col2" >['Bob Smith']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_9e630 th {
#   font-size: 120%;
# }
# #T_9e630  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_9e630" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e630_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_9e630_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e630_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9e630_row0_col0" class="data row0 col0" >Design Phase</td>
#       <td id="T_9e630_row0_col1" class="data row0 col1" >['1', '2']</td>
#     </tr>
#     <tr>
#       <th id="T_9e630_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9e630_row1_col0" class="data row1 col0" >Development Phase</td>
#       <td id="T_9e630_row1_col1" class="data row1 col1" >['3', '4', '5', '6', '7', '8', '9', '10']</td>
#     </tr>
#   </tbody>
# </table>
